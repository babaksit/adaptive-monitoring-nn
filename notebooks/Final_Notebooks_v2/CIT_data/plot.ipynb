# %%
import pandas as pd

# %%
df  = pd.read_csv("../../../logs/0.0135_4/merged.csv")

# %%
df["read_bytes_rate"][:10100].plot()
# Out:
# <AxesSubplot:>

# %%
import pickle
with open('../../../logs/0.01_4/merged_dic.pkl','rb') as f:
     ff = pickle.load(f)

# %%
ff["cpu_rate"][10]
# Out:
# <TimeSeries (DataArray) (Time: 361, component: 1, sample: 1)>
# array([[[0.32851939]],
#
#        [[0.32740848]],
#
#        [[0.32265482]],
#
#        [[0.32159558]],
#
#        [[0.31813367]],
#
#        [[0.31606686]],
#
#        [[0.31446508]],
#
#        [[0.31221743]],
#
#        [[0.31025396]],
#
#        [[0.30818715]],
#
# ...
#
#        [[0.25504431]],
#
#        [[0.25612938]],
#
#        [[0.25747281]],
#
#        [[0.25881623]],
#
#        [[0.26039218]],
#
#        [[0.26266567]],
#
#        [[0.2645258 ]],
#
#        [[0.26543003]],
#
#        [[0.26235565]],
#
#        [[0.26594673]]])
# Coordinates:
#   * Time       (Time) datetime64[ns] 2022-06-05T15:31:42 ... 2022-06-05T15:37:42
#   * component  (component) object 'cpu_rate'
# Dimensions without coordinates: sample

# %%
import darts
from matplotlib.pyplot import figure

ii = 0 
figure(figsize=(10, 6), dpi=120)
for l in ff['read_bytes_rate']:
    ii+=1
    if  ii < 2 or ii > 27 :
        continue
#     if not l.is_deterministic:
    l.plot()

# %% [markdown]
# # l.

# %%
a.concatenate(b)
# Out:
# [2022-05-31 14:35:34,048] ERROR | main_logger | ValueError: when concatenating along time dimension, the component and sample dimensions of all provided series must match.
# [2022-05-31 14:35:34,048] ERROR | main_logger | ValueError: when concatenating along time dimension, the component and sample dimensions of all provided series must match.
# [2022-05-31 14:35:34,048] ERROR | main_logger | ValueError: when concatenating along time dimension, the component and sample dimensions of all provided series must match.
# [2022-05-31 14:35:34,048] ERROR | main_logger | ValueError: when concatenating along time dimension, the component and sample dimensions of all provided series must match.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-138-153cfdb39e3b> in <module>
# ----> 1 a.concatenate(b)
#
# ...

# %%
a.append(b)
# Out:
# [2022-05-31 14:37:51,252] ERROR | darts.timeseries | ValueError: Both series must have the same number of components.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-140-d6231792f85d> in <module>
# ----> 1 a.append(b)
#
# ~/.conda/envs/thesis/lib/python3.8/site-packages/darts/timeseries.py in append(self, other)
#    1840             logger,
#    1841         )
# -> 1842         raise_if_not(
#    1843             other.n_samples == self.n_samples,
#    1844             "Both series must have the same number of components.",
#
# ~/.conda/envs/thesis/lib/python3.8/site-packages/darts/logging.py in raise_if_not(condition, message, logger)
#      58     if not condition:
#      59         logger.error("ValueError: " + message)
# ---> 60         raise ValueError(message)
#      61
#      62
#
# ValueError: Both series must have the same number of components.

# %%
b.values().reshape(300,100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-146-761225f935f0> in <module>
# ----> 1 b.values().reshape(300,100)
#
# ValueError: cannot reshape array of size 311 into shape (300,100)

# %%
c = b[0]

# %%
b.univariate_values
# Out:
# <bound method TimeSeries.univariate_values of <TimeSeries (DataArray) (Time: 311, component: 1, sample: 1)>
# array([[[       nan]],
#
#        [[       nan]],
#
#        [[       nan]],
#
#        [[       nan]],
#
#        [[       nan]],
#
#        [[       nan]],
#
#        [[       nan]],
#
#        [[       nan]],
#
#        [[       nan]],
#
#        [[       nan]],
#
# ...
#
#        [[0.25832537]],
#
#        [[0.25773116]],
#
#        [[0.25698194]],
#
#        [[0.25605188]],
#
#        [[0.25605188]],
#
#        [[0.25003229]],
#
#        [[0.2529775 ]],
#
#        [[0.25481179]],
#
#        [[0.25491513]],
#
#        [[0.25313251]]])
# Coordinates:
#   * Time       (Time) datetime64[ns] 2022-05-31T12:34:00 ... 2022-05-31T12:39:10
#   * component  (component) object 'cpu_rate'
# Dimensions without coordinates: sample>

# %%
a = ff['cpu_rate'][30]
b = ff['cpu_rate'][31]

# %%
a.concatenate(b)
# Out:
# [2022-05-31 14:26:27,017] ERROR | main_logger | ValueError: when concatenating along time dimension, the component and sample dimensions of all provided series must match.
# [2022-05-31 14:26:27,017] ERROR | main_logger | ValueError: when concatenating along time dimension, the component and sample dimensions of all provided series must match.
# [2022-05-31 14:26:27,017] ERROR | main_logger | ValueError: when concatenating along time dimension, the component and sample dimensions of all provided series must match.
# [2022-05-31 14:26:27,017] ERROR | main_logger | ValueError: when concatenating along time dimension, the component and sample dimensions of all provided series must match.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-125-153cfdb39e3b> in <module>
# ----> 1 a.concatenate(b)
#
# ...
