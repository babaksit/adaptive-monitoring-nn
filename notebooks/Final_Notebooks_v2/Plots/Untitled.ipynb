# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from darts import TimeSeries
from darts.datasets import AirPassengersDataset

# %%
from darts.datasets import HeartRateDataset
from darts.datasets import TemperatureDataset
from darts.datasets import TaylorDataset
from darts.datasets import WoolyDataset
from darts.datasets import SunspotsDataset
from darts.datasets import GasRateCO2Dataset

# %%
series = SunspotsDataset().load()
series.plot()

# %%
TimeSeries.from_values(series.values()).plot()
